# %% [markdown]
# <a href="https://colab.research.google.com/github/nathalycuenca1-cloud/hola-mundo/blob/master/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# lenguaje de Python:
#
# Es un lenguaje sencillo de usar que sirve para desarrolar app, automatizar tareas entre muchas cosas mas.

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# Lenguaje R:
#
# R es un lenguaje usado para estadistica, analisis de datos y graficos

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# lenguaje javaScript:
#
# JavaScript es un lenguaje de programacion utilizado para crear paginas web interactivas y aplicaciones web.

# %%
console.log("Hola mundo");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4313/2214721816.py in <cell line: 0>()
# ----> 1 console. log("Hola mundo");
#
# NameError: name 'console' is not defined
